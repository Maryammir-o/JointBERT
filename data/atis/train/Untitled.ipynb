# %%
with open ('seq.out') as f:
    slots= f.read()

# %%
slots
# Out:
# 'NoLabel NoLabel NoLabel B-weather/noun I-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-weather/noun I-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-weather/noun I-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-weather/noun I-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-weather/noun I-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-datetime B-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-datetime B-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-datetime B-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-datetime B-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel NoLabel B-datetime B-weather/noun NoLabel B-location I-location I-location\nNoLabel NoLabel B-datetime B-weather/noun NoLabel B-locat
# ...

# %%
slots_n = slots.replace('\n', ' ')

# %%
set(slots_n.split(' '))
# Out:
# {'',
#  'B-alarm/alarm_modifier',
#  'B-datetime',
#  'B-location',
#  'B-negation',
#  'B-news/type',
#  'B-reminder/noun',
#  'B-reminder/recurring_period',
#  'B-reminder/reference',
#  'B-reminder/reminder_modifier',
#  'B-reminder/todo',
#  'B-timer/attributes',
#  'B-timer/noun',
#  'B-weather/attribute',
#  'B-weather/noun',
#  'B-weather/temperatureUnit',
#  'I-alarm/alarm_modifier',
#  'I-datetime',
#  'I-location',
#  'I-reminder/noun',
#  'I-reminder/recurring_period',
#  'I-reminder/reference',
#  'I-reminder/reminder_modifier',
#  'I-reminder/todo',
#  'I-weather/attribute',
#  'I-weather/noun',
#  'NoLabel'}

# %%
with open ('label') as f:
    labels= f.read()

# %%
labels
# Out:
# 'weather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nweather/find\nwea
# ...

# %%
label_n = labels.split("\n")

# %%
label_r = set(label_n)

# %%
label_r
# Out:
# {'',
#  'alarm/cancel_alarm',
#  'alarm/modify_alarm',
#  'alarm/set_alarm',
#  'alarm/show_alarms',
#  'alarm/snooze_alarm',
#  'alarm/time_left_on_alarm',
#  'reminder/cancel_reminder',
#  'reminder/set_reminder',
#  'reminder/show_reminders',
#  'weather/checkSunrise',
#  'weather/checkSunset',
#  'weather/find'}
